# %% [markdown]
# # 예상 주제 선정

# %% [markdown]
# # 올바른 재활용 분류를 위한 빅데이터 분류 서비스

# %% [markdown]
# ## 세부사항
# 재활용품 분류 및 선별 데이터를 이용하여 재활용품 분류 및 선별 정확도 및 인식 속도를 개선할 수 있는 자동 분류 구축이나 자동화 로봇 및 시스템 개발 서비스

# %% [markdown]
# * https://aihub.or.kr/aihubdata/data/view.do?currMenu=115&topMenu=100&aihubDataSe=realm&dataSetSn=71362  (재활용품 분류 및 선별 데이터)
# * https://aihub.or.kr/aihubdata/data/view.do?currMenu=115&topMenu=100&aihubDataSe=realm&dataSetSn=71385  (생활폐기물 데이터)

# %% [markdown]
# ## 유사사례
# * https://mediahub.seoul.go.kr/archives/2000534 (AI 자원 회수로봇 '네프론')
# * https://www.sedaily.com/NewsView/1ZAAFPE9W5 (세븐일레븐, 캔·페트병 자동 수거 ‘AI 로봇')

# %% [markdown]
# ## 관련 논문
# * https://koreascience.kr/article/CFKO201904533856580.pdf

# %% [markdown]
# # 빅데이터를 이용한 철로사고방지 예측 서비스

# %% [markdown]
# ## 세부사항
# 철도 선로 상태 인식 데이터를 활용, 철로 선로 상태 데이터를 딥러닝에 학습시켜 철도 운영에서 발생할 수 있는 사고를 조기에 대응할 수 있도록 정보를 제공해주는 웹 서비스 구현
#
# * 최초 주제를 구상했을 때 생각했던 부분은 딥러닝 구현을 통해 철도 운영에서 발생할 수 있는 사고예방에 필요한 정보를 웹 사이트에 구현
# * 예를 들어, 레일의 어떤 부분이 정상 데이터와 비교했을 때 이상현상이라 판단되는 경우 사고발생 가능성이 높을 것으로 예상된다는 등의 정보를 사이트에 표시<br>
# (나아가서 철로 곳곳 cctv를 설치하고 사이트와 연동하여 모니터링 시스템구축을 제안 해볼수도 있을 것 같음)

# %% [markdown]
# ## 데이터셋
# ### 이미지데이터, 라벨링 -> 바운딩, 세그멘테이션
# * https://aihub.or.kr/aihubdata/data/view.do?currMenu=115&topMenu=100&aihubDataSe=realm&dataSetSn=71391 (철도 선로 상태 인식 데이터)
# * https://aihub.or.kr/aihubdata/data/view.do?currMenu=115&topMenu=100&aihubDataSe=realm&dataSetSn=71403 (전차선 애자 상태 인식 데이터
#
# ### CSV데이터
# * https://www.data.go.kr/data/15079935/fileData.do (한국교통안전공단_국내 철도사고 및 운행장애 발생 정보)
# * https://www.data.go.kr/data/3047220/fileData.do (한국교통안전공단_철도사고 통계현황)

# %% [markdown]
# * 도메인 지식 필요 -> 레일 이음매에 사용되는 자재와 같이 철로자재에 대한 지식, 철도 선로점검지침, 철도안전사고와 관련된 도메인 지식 등

# %% [markdown]
# ### 데이터분석 및 머신러닝/딥러닝
# * 데이터분석 -> 유형별 철도사고, 월별 유형별 철도사고
# * 딥러닝 구현 -> 유효성 검증: 아마 yolov5, Mask R-cnn의 모델중에 사용(모델에 대한 학습 필요)

# %% [markdown]
# ## 참고문헌
# * https://koreascience.kr/article/JAKO201407559762098.pdf
# * https://koreascience.kr/article/CFKO200821041235039.pdf

# %% [markdown]
# ## 유사사례
# * https://www.hellot.net/news/article.html?no=39085
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 사고사례
# * https://www.sisain.co.kr/news/articleView.html?idxno=49045
# * https://www.pressian.com/pages/articles/2023061011410056450?utm_source=naver&utm_medium=search
# * https://news.kbs.co.kr/news/view.do?ncd=7691176&ref=A

# %% [markdown]
# 국내는 철도관제원이 CCTV모니터링하는 시스템

# %% [markdown]
# ## 스토리(시나리오)
# 1. 주제선정이유 – 사고사례 언급을 통해 철도사고예방 필요성 인식
# 2. 분석 및 ML/DL – aihub데이터를 활용
# 3. 웹 서비스 구현? – 분석 및 ML/DL의 결과를 웹사이트에 정보시스템처럼 구현
# 4. 활용방안 – 서비스 구현을 통해 철도 선로사고예방을 위한 보조적인 역할 가능, 여기에 cctv구축을 통한 모니터링 시스템구축을 추가적으로 제안

# %% [markdown]
# # 빅데이터 분석기반의 문화여가 지표 서비스 개발

# %% [markdown]
# ## 세부사항
# 문화, 여가등의 데이터 및 활동지수 데이터를 이용하여 사람들의 문화여가 양상을 파악 후, 어떤 경향을 가지는지 웹에 지표들을 구현…? 조사하고 보니 다른 주제들보단 가벼운 느낌

# %% [markdown]
# * https://www.g2b.go.kr/pt/menu/selectSubFrame.do?framesrc=https://www.g2b.go.kr:8340/search.do?category=TGONG&kwd=%BA%F2%B5%A5%C0%CC%C5%CD%20%BC%AD%BA%F1%BD%BA

# %% [markdown]
# ## 데이터셋
# * http://data.seoul.go.kr/dataList/10557/S/2/datasetView.do (서울시 하고 싶은 여가활동 통계)
# * http://data.seoul.go.kr/dataList/10260/S/2/datasetView.do (서울시 주말, 휴일 여가활동 통계)
# * https://kosis.kr/statHtml/statHtml.do?orgId=113&tblId=DT_113_STBL_1028411&vw_cd=MT_ZTITLE&list_id=113_11314_002&seqNo=&lang_mode=ko&language=kor&obj_var_id=&itm_id=&conn_path=MT_ZTITLE (공공문화여가시설_공공문화 및 여가시설 만족도)
# * 필요시 인스타 크롤링

# %% [markdown]
# * 공공데이터나 서울열린데이터광장에서 문화 여가 관련데이터를 찾거나, 크롤링이 추가적으로 필요할거같은 주제(예를 들면 우리 배웠던 인스타?)
# * 도메인 지식 -> 활동지수 계산법?

# %% [markdown]
# ### 데이터분석 및 머신러닝/딥러닝
# * 데이터분석 -> 성별, 연령별 선호하는 여가활동, 주말, 휴일 사람들의 여가활동분포, 성별, 연령별 공공문화 및 여가시설 만족도 등등
# * ML/DL -> 마땅히 어떤 모델을 사용해야할지 모르겠음. 한다면 ML쪽에 가깝다고 생각됨

# %% [markdown]
# ## 유사사례

# %% [markdown]
# ## 스토리(시나리오)
# 1. **주제선정이유** – 코로나 종식 이후 다시 사람들이 예전처럼 문화생활을 즐길 수 있게 됨에 따라 사람들마다 문화 및 여가생활을 어떻게 즐기고, 어떤 추세를 띄는지 분석하고자 선정
# 2. **분석 및 ML/DL** – 데이터를 토대로 다양한 분석(시각화), 머신러닝을 사용할 수 있을지는 아직 모르겠음
# 3. **웹 서비스 구현** – 산출된 결과(시각화 지표나 표같은거) 사이트에 구현(제안요청서에 예시비슷한 그림처럼)추후 데이터가 변경되면 업데이트가 되는 방식?
# 4. **활용방안** – 사람들이 어떤 문화생활을 하며 스트레스를 해소하는지 한눈에 보기 좋아 자기계발을 하고자 하는 사람들은 참고해서 취미생활을 만들어보자..?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 산사태 빅데이터 구축 및 토사재해 취약성 평가 모델

# %% [markdown]
# ## 세부사항
# GIS 공간정보, 지형-지반 특성 데이터, 날씨데이터 등을 활용하여 산사태 위험 지역을 파악 후 산사태에 영향을 주는 요인들 분석 및 예측모델 제시 후, 태풍이나 폭우가 집중되는 기간에 취약지역에 재난문자처럼 웹에서 예상 위험지역을 제공해주는 시스템

# %% [markdown]
# * https://ebid.kisti.re.kr/kisti_bidding/outer/bidding/bidnotice/bidnoticeDetail.do?bidNo=B2023-000394&bidNoNext=01

# %% [markdown]
# * 산림공간정보서비스의 gis데이터와 기상청데이터를 활용가능
# * 도메인지식 -> 토사재해, 자연재난행동요령 등
# * 데이터분석/시각화, 머신러닝도 가능은 해보임(어떤 모델을 사용할지는 아직 구체적으로 생각하긴 힘들듯)

# %% [markdown]
# * 자연재난행동요령: https://www.safekorea.go.kr/idsiSFK/neo/sfk/cs/contents/prevent/prevent20.html?menuSeq=126

# %% [markdown]
# * [산림공간정보서비스] https://www.forest.go.kr/kfsweb/kfi/kfs/trail/sanSaTae.do?pblicDataId=PBD0000210&tabs=4&mn=NKFS_06_08_02&subTitle=%ec%82%b0%ec%82%ac%ed%83%9c%ec%9c%84%ed%97%98%ec%a7%80%eb%8f%84
# * [기상청데이터] https://data.kma.go.kr/data/grnd/selectAsosRltmList.do?pgmNo=36

# %% [markdown]
# ### 데이터분석 및 머신러닝/딥러닝
# *

# %% [markdown]
# ## 유사사례
# * 산사태 예측정보 제공: https://www.nongmin.com/article/20230612500443

# %% [markdown]
# ## 관련논문
# * 논문[최대 엔트로피 모형을 활용한 기후변화 시나리오 기반 산사태 취약성 평가] https://ekscc.re.kr/xml/36552/36552.pdf

# %% [markdown]
# ## 사고사례
# * 강원도 횡성 산사태: https://www.ytn.co.kr/_ln/0115_202306201334136752

# %% [markdown]
# ## 스토리(시나리오)
# 1. 주제선정이유 – 사고사례언급을 통해 매년 일어나는 산사태에 대한 위험성 언급
# 2. 분석 및 ML/DL – 공공데이터, gis데이터와 기상청데이터를 활용하여 분석 및 예측모델 개발
# 3. 웹 서비스 구현 – [산림공간정보서비스]의 지도처럼 특정 지역의 산사태 위험구간을 지도에 매핑한 것을 웹사이트에 구현?
# 4. 활용방안 – 산사태 위험지역의 주민 또는 관련 기관의 피해를 최소화, 담당기관에 대비정책 및 피해복구방안에 도움
